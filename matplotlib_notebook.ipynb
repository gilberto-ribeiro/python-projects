# %% [markdown]
# Importar bibliotecas

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('default')

# %%
fig, ax = plt.subplots()
ax.plot([1, 2, 3, 4], [1, 4, 2, 3])
plt.show()

# %%
np.random.seed(19680801)  # seed the random number generator.
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')
plt.show()

# %%
x = np.linspace(0, 2, 100)

fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
ax.plot(x, x, label='linear')
ax.plot(x, x**2, label='quadratic')
ax.plot(x, x**3, label='cubic')
ax.set_xlabel('x label')
ax.set_ylabel('y label')
ax.set_title('Simple Plot')
ax.legend()
plt.show()

# %%
def my_plotter(ax, data1, data2, param_dic):
    return ax.plot(data1, data2, **param_dic)

# %%
data1, data2, data3, data4 = np.random.randn(4, 100)

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(5, 2.7))
my_plotter(ax1, data1, data2, {'marker': 'x'})
my_plotter(ax2, data3, data4, {'marker': 'o'})
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
x = np.arange(len(data1))
j, = ax.plot(x, np.cumsum(data1), color='C3', linewidth=3, linestyle='--')
l, = ax.plot(x, np.cumsum(data2), color='C2', linewidth=2)
l.set_linestyle(':')
# j.set_color('black')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.scatter(data1, data2, s=50, facecolor='C6', edgecolor='k')

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.plot(data1, 'o', label='data1')
ax.plot(data2, 'd', label='data2')
ax.plot(data3, 'v', label='data3')
ax.plot(data4, 's', label='data4')
ax.legend()
plt.show()

# %%
mu, sigma = 115, 15
x = mu + sigma * np.random.randn(10000)
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
# the histogram of the data
n, bins, patches = ax.hist(x, 50, density=True, facecolor='C0', alpha=0.75)

ax.set_xlabel('Length [cm]')
ax.set_ylabel('Probability')
ax.set_title('Aardvark lengths\n (not really)')
ax.text(75, .025, r'$\mu=115,\ \sigma=15$')
ax.axis([55, 175, 0, 0.03])
ax.grid(True)
t = ax.set_xlabel('my data', fontsize=14, color='red')
ax.set_title(r'$\sigma_i=15$')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2 * np.pi * t)
line, = ax.plot(t, s, lw=2)

ax.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
            arrowprops=dict(facecolor='black', shrink=0.05))

ax.set_ylim(-2, 2)
# Out:
# (-2.0, 2.0)

# %%
fig, ax = plt.subplots(figsize=(5, 2.7))
ax.plot(np.arange(len(data1)), data1, label='data1')
ax.plot(np.arange(len(data2)), data2, label='data2')
ax.plot(np.arange(len(data3)), data3, 'd', label='data3')
ax.legend()
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(5, 2.7), layout='constrained')
xdata = np.arange(len(data1))  # make an ordinal for this
data = 10**data1
axs[0].plot(xdata, data)

axs[1].set_yscale('log')
axs[1].plot(xdata, data)
plt.show()

# %%
fig, axs = plt.subplots(2, 1, layout='constrained')

axs[0].plot(xdata, data)
axs[0].set_title('Automatic ticks', color='blue')

axs[1].plot(xdata, data)
axs[1].set_xticks(np.arange(0, 100, 30), ['zero', '30', 'sixty', '90'])
axs[1].set_yticks([10, 30, 50, 70])
axs[1].set_title('Manual ticks', color='red')
axs[1].text(40, 40, '40-40', size='xx-small', c='green')

plt.show()

# %%
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
dates = np.arange(np.datetime64('2021-11-15'), np.datetime64('2021-12-25'),
                  np.timedelta64(1, 'h'))
data = np.cumsum(np.random.randn(len(dates)))
ax.plot(dates, data)
cdf = mpl.dates.ConciseDateFormatter(ax.xaxis.get_major_locator())
ax.xaxis.set_major_formatter(cdf)

# %%
fig, ax = plt.subplots(figsize=(5, 2.7), layout='constrained')
categories = ['turnips', 'rutabaga', 'cucumber', 'pumpkins']
num = np.random.rand(len(categories))
ax.bar(categories, num, color='crimson')
ax.text(1, num[1], 'teste', weight='black', color='pink')
plt.show()

# %%
fig, (ax1, ax3) = plt.subplots(1, 2, figsize=(7, 2.7), layout='constrained')
l1, = ax1.plot(t, s)
ax2 = ax1.twinx()
l2, = ax2.plot(t, range(len(t)), color='pink')
# ax1.legend()
ax2.legend([l1, l2], ['Sine (left)', 'Straigt (right)'], loc='center')
ax3.plot(t, s)
ax3.set_xlabel('Angle [rad]')
ax4 = ax3.secondary_xaxis('top', functions=(np.rad2deg, np.deg2rad))
ax4.set_xlabel('Angle [°]')
ax1.set_xlim((1, 3))
ax2.set_ylim((200, 300))
plt.show()

# %%
x = np.arange(-10, 10, 0.01)
fig, axs = plt.subplot_mosaic([['0', '2', '2'],
                               ['1', '2', '2']], figsize=(10, 5))

for i in range(1, 4):
    axs['0'].plot(x, np.cos(i * x), color=f'C{i-1}')
    axs['1'].plot(x, np.sin(i * x), color=f'C{i+2}')
    axs['2'].plot(x, x**i, color=f'C{i+5}')
axs['0'].set_title('Cosseno')
axs['1'].set_title('Seno')
axs['2'].set_title('Polinômio')
fig.subplots_adjust(hspace=0.5, wspace=0.3)
for i in range(3):
    axs[str(i)].set_xlabel('Eixo x')
    axs[str(i)].set_ylabel('Eixo y')
    axs[str(i)].set_xlim((0, 10))
axs['2'].set_xlim((-10, 10))
axs['2'].set_ylim((-100, 100))
plt.show()
