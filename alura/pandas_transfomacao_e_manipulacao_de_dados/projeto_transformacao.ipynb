# %% [markdown]
# # Aula 1

# %%
import pandas as pd

# %%
moveis_disponiveis = pd.read_json('https://caelum-online-public.s3.amazonaws.com/2928-transformacao-manipulacao-dados/moveis_disponiveis.json')
dados_hospedagem = pd.read_json('https://caelum-online-public.s3.amazonaws.com/2928-transformacao-manipulacao-dados/dados_hospedagem.json')

# %%
dados_hospedagem.head()
# Out:
#                                          info_moveis
# 0  {'avaliacao_geral': '10.0', 'experiencia_local...
# 1  {'avaliacao_geral': '10.0', 'experiencia_local...
# 2  {'avaliacao_geral': '10.0', 'experiencia_local...
# 3  {'avaliacao_geral': '10.0', 'experiencia_local...
# 4  {'avaliacao_geral': '10.0', 'experiencia_local...

# %%
dados_hospedagem = pd.json_normalize(dados_hospedagem['info_moveis'])

# %%
dados_hospedagem.head()
# Out:
#   avaliacao_geral experiencia_local max_hospedes  \
# 0            10.0                --            1
# 1            10.0                --           10
# 2            10.0                --           11
# 3            10.0                --           12
# 4            10.0                --           14
#
#                                      descricao_local  \
# 0  [This clean and comfortable one bedroom sits r...
# 1  [Welcome to the heart of the 'Ballard Brewery ...
# 2  [New modern house built in 2013.  Spectacular ...
# 3  [Our NW style home is 3200+ sq ft with 3 level...
# 4  [Perfect for groups. 2 bedrooms, full bathroom...
#
#                                 descricao_vizinhanca  \
# 0  [Lower Queen Anne is near the Seattle Center (...
# 1  [--, Capital Hill is the heart of Seattle, bor...
# 2  [Upper Queen Anne is a charming neighborhood f...
# 3  [The Views from our top floor!  Wallingford ha...
# 4  [Safeway grocery store within walking distance...
#
# ...

# %% [markdown]
# # Aula 2

# %%
colunas = list(dados_hospedagem.columns)
colunas
# Out:
# ['avaliacao_geral',
#  'experiencia_local',
#  'max_hospedes',
#  'descricao_local',
#  'descricao_vizinhanca',
#  'quantidade_banheiros',
#  'quantidade_quartos',
#  'quantidade_camas',
#  'modelo_cama',
#  'comodidades',
#  'taxa_deposito',
#  'taxa_limpeza',
#  'preco']

# %%
dados_hospedagem = dados_hospedagem.explode(column=colunas[3:])
dados_hospedagem.head()
# Out:
#   avaliacao_geral experiencia_local max_hospedes  \
# 0            10.0                --            1
# 0            10.0                --            1
# 0            10.0                --            1
# 0            10.0                --            1
# 0            10.0                --            1
#
#                                      descricao_local  \
# 0  This clean and comfortable one bedroom sits ri...
# 0  Our century old Upper Queen Anne house is loca...
# 0  Cozy room in two-bedroom apartment along the l...
# 0  Very lovely and cozy room for one. Convenientl...
# 0  The “Studio at Mibbett Hollow' is in a Beautif...
#
#                                 descricao_vizinhanca quantidade_banheiros  \
# 0  Lower Queen Anne is near the Seattle Center (s...                    1
# 0  Upper Queen Anne is a really pleasant, unique ...                    1
# 0  The convenience of being in Seattle but on the...                    1
# ...

# %%
dados_hospedagem.reset_index(inplace=True, drop=True)
dados_hospedagem.head()
# Out:
#   avaliacao_geral experiencia_local max_hospedes  \
# 0            10.0                --            1
# 1            10.0                --            1
# 2            10.0                --            1
# 3            10.0                --            1
# 4            10.0                --            1
#
#                                      descricao_local  \
# 0  This clean and comfortable one bedroom sits ri...
# 1  Our century old Upper Queen Anne house is loca...
# 2  Cozy room in two-bedroom apartment along the l...
# 3  Very lovely and cozy room for one. Convenientl...
# 4  The “Studio at Mibbett Hollow' is in a Beautif...
#
#                                 descricao_vizinhanca quantidade_banheiros  \
# 0  Lower Queen Anne is near the Seattle Center (s...                    1
# 1  Upper Queen Anne is a really pleasant, unique ...                    1
# 2  The convenience of being in Seattle but on the...                    1
# ...

# %%
import numpy as np

# %%
colunas_numericas = ['max_hospedes', 'quantidade_banheiros', 'quantidade_quartos', 'quantidade_camas']
dados_hospedagem[colunas_numericas] = dados_hospedagem[colunas_numericas].astype(np.int64)
dados_hospedagem['avaliacao_geral'] = dados_hospedagem['avaliacao_geral'].astype(np.float64)
dados_hospedagem.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3818 entries, 0 to 3817
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   avaliacao_geral       3162 non-null   float64
#  1   experiencia_local     3818 non-null   object
#  2   max_hospedes          3818 non-null   int64
#  3   descricao_local       3818 non-null   object
#  4   descricao_vizinhanca  3818 non-null   object
#  5   quantidade_banheiros  3818 non-null   int64
#  6   quantidade_quartos    3818 non-null   int64
#  7   quantidade_camas      3818 non-null   int64
#  8   modelo_cama           3818 non-null   object
#  9   comodidades           3818 non-null   object
#  10  taxa_deposito         3818 non-null   object
#  11  taxa_limpeza          3818 non-null   object
#  12  preco                 3818 non-null   object
# dtypes: float64(1), int64(4), object(8)
# memory usage: 387.9+ KB

# %%
# colunas_dinheiro = ['taxa_deposito', 'taxa_limpeza', 'preco']
# for coluna in colunas_dinheiro:
#     dados_hospedagem[coluna] = dados_hospedagem[coluna].str.replace('$', '')
#     dados_hospedagem[coluna] = dados_hospedagem[coluna].str.replace(',', '')
# dados_hospedagem[colunas_dinheiro] = dados_hospedagem[colunas_dinheiro].astype(np.float64)

# %%
dados_hospedagem['preco'] = dados_hospedagem['preco'].apply(lambda x: x.replace('$', '').replace(',', '').strip())

# %%
colunas_taxas = ['taxa_deposito', 'taxa_limpeza']
dados_hospedagem[colunas_taxas] = dados_hospedagem[colunas_taxas].applymap(lambda x: x.replace('$', '').replace(',', '').strip())
dados_hospedagem[colunas_taxas] = dados_hospedagem[colunas_taxas].astype(np.float64)
dados_hospedagem.head()
# Out:
#    avaliacao_geral experiencia_local  max_hospedes  \
# 0             10.0                --             1
# 1             10.0                --             1
# 2             10.0                --             1
# 3             10.0                --             1
# 4             10.0                --             1
#
#                                      descricao_local  \
# 0  This clean and comfortable one bedroom sits ri...
# 1  Our century old Upper Queen Anne house is loca...
# 2  Cozy room in two-bedroom apartment along the l...
# 3  Very lovely and cozy room for one. Convenientl...
# 4  The “Studio at Mibbett Hollow' is in a Beautif...
#
#                                 descricao_vizinhanca  quantidade_banheiros  \
# 0  Lower Queen Anne is near the Seattle Center (s...                     1
# 1  Upper Queen Anne is a really pleasant, unique ...                     1
# 2  The convenience of being in Seattle but on the...                     1
# ...

# %% [markdown]
# # Aula 3

# %%
dados_hospedagem['descricao_local'] = dados_hospedagem['descricao_local'].str.lower()
dados_hospedagem.head()
# Out:
#    avaliacao_geral experiencia_local  max_hospedes  \
# 0             10.0                --             1
# 1             10.0                --             1
# 2             10.0                --             1
# 3             10.0                --             1
# 4             10.0                --             1
#
#                                      descricao_local  \
# 0  this clean and comfortable one bedroom sits ri...
# 1  our century old upper queen anne house is loca...
# 2  cozy room in two-bedroom apartment along the l...
# 3  very lovely and cozy room for one. convenientl...
# 4  the “studio at mibbett hollow' is in a beautif...
#
#                                 descricao_vizinhanca  quantidade_banheiros  \
# 0  Lower Queen Anne is near the Seattle Center (s...                     1
# 1  Upper Queen Anne is a really pleasant, unique ...                     1
# 2  The convenience of being in Seattle but on the...                     1
# ...

# %%
dados_hospedagem['descricao_local'] = dados_hospedagem['descricao_local'].str.replace("[^\w\-\']", ' ', regex=True)
dados_hospedagem['descricao_local'] = dados_hospedagem['descricao_local'].str.replace("(?<!\w)-(?!\w)", ' ', regex=True)
dados_hospedagem['descricao_local'] = dados_hospedagem['descricao_local'].str.split()
dados_hospedagem.head()
# Out:
#    avaliacao_geral experiencia_local  max_hospedes  \
# 0             10.0                --             1
# 1             10.0                --             1
# 2             10.0                --             1
# 3             10.0                --             1
# 4             10.0                --             1
#
#                                      descricao_local  \
# 0  [this, clean, and, comfortable, one, bedroom, ...
# 1  [our, century, old, upper, queen, anne, house,...
# 2  [cozy, room, in, two-bedroom, apartment, along...
# 3  [very, lovely, and, cozy, room, for, one, conv...
# 4  [the, studio, at, mibbett, hollow', is, in, a,...
#
#                                 descricao_vizinhanca  quantidade_banheiros  \
# 0  Lower Queen Anne is near the Seattle Center (s...                     1
# 1  Upper Queen Anne is a really pleasant, unique ...                     1
# 2  The convenience of being in Seattle but on the...                     1
# ...

# %%
dados_hospedagem['comodidades'] = dados_hospedagem['comodidades'].str.replace('\{|\}|\"', '', regex=True)
dados_hospedagem['comodidades'] = dados_hospedagem['comodidades'].str.split(',')
dados_hospedagem.head()
# Out:
#    avaliacao_geral experiencia_local  max_hospedes  \
# 0             10.0                --             1
# 1             10.0                --             1
# 2             10.0                --             1
# 3             10.0                --             1
# 4             10.0                --             1
#
#                                      descricao_local  \
# 0  [this, clean, and, comfortable, one, bedroom, ...
# 1  [our, century, old, upper, queen, anne, house,...
# 2  [cozy, room, in, two-bedroom, apartment, along...
# 3  [very, lovely, and, cozy, room, for, one, conv...
# 4  [the, studio, at, mibbett, hollow', is, in, a,...
#
#                                 descricao_vizinhanca  quantidade_banheiros  \
# 0  Lower Queen Anne is near the Seattle Center (s...                     1
# 1  Upper Queen Anne is a really pleasant, unique ...                     1
# 2  The convenience of being in Seattle but on the...                     1
# ...

# %%
dados_hospedagem['descricao_vizinhanca'] = dados_hospedagem['descricao_vizinhanca'].str.lower()
dados_hospedagem['descricao_vizinhanca'] = dados_hospedagem['descricao_vizinhanca'].str.replace('[^\w\-\']', ' ', regex=True)
dados_hospedagem['descricao_vizinhanca'] = dados_hospedagem['descricao_vizinhanca'].str.replace('(?<!\w)-(?!\w)', ' ', regex=True)
dados_hospedagem['descricao_vizinhanca'] = dados_hospedagem['descricao_vizinhanca'].str.split()
dados_hospedagem.head()
# Out:
#    avaliacao_geral experiencia_local  max_hospedes  \
# 0             10.0                --             1
# 1             10.0                --             1
# 2             10.0                --             1
# 3             10.0                --             1
# 4             10.0                --             1
#
#                                      descricao_local  \
# 0  [this, clean, and, comfortable, one, bedroom, ...
# 1  [our, century, old, upper, queen, anne, house,...
# 2  [cozy, room, in, two-bedroom, apartment, along...
# 3  [very, lovely, and, cozy, room, for, one, conv...
# 4  [the, studio, at, mibbett, hollow', is, in, a,...
#
#                                 descricao_vizinhanca  quantidade_banheiros  \
# 0  [lower, queen, anne, is, near, the, seattle, c...                     1
# 1  [upper, queen, anne, is, a, really, pleasant, ...                     1
# 2  [the, convenience, of, being, in, seattle, but...                     1
# ...

# %% [markdown]
# # Aula 4

# %%
moveis_disponiveis['data'] = pd.to_datetime(moveis_disponiveis['data'])
moveis_disponiveis
# Out:
#           id       data  vaga_disponivel    preco
# 0        857 2016-01-04            False     None
# 1        857 2016-01-05            False     None
# 2        857 2016-01-06            False     None
# 3        857 2016-01-07            False     None
# 4        857 2016-01-08            False     None
# ...      ...        ...              ...      ...
# 364995  3279 2016-12-29             True  $140.00
# 364996  3279 2016-12-30             True  $140.00
# 364997  3279 2016-12-31             True  $140.00
# 364998  3279 2017-01-01             True  $140.00
# 364999  3279 2017-01-02            False     None
#
# [365000 rows x 4 columns]

# %%
moveis_disponiveis['ano-mes'] = moveis_disponiveis['data'].dt.strftime('%Y-%m')
moveis_disponiveis
# Out:
#           id       data  vaga_disponivel    preco  ano-mes
# 0        857 2016-01-04            False     None  2016-01
# 1        857 2016-01-05            False     None  2016-01
# 2        857 2016-01-06            False     None  2016-01
# 3        857 2016-01-07            False     None  2016-01
# 4        857 2016-01-08            False     None  2016-01
# ...      ...        ...              ...      ...      ...
# 364995  3279 2016-12-29             True  $140.00  2016-12
# 364996  3279 2016-12-30             True  $140.00  2016-12
# 364997  3279 2016-12-31             True  $140.00  2016-12
# 364998  3279 2017-01-01             True  $140.00  2017-01
# 364999  3279 2017-01-02            False     None  2017-01
#
# [365000 rows x 5 columns]

# %%
def tratar_preco(linha):
    if linha is None or linha == 'None':
        linha = '0.00'
    else:
        linha = linha.replace('$', '').replace(',', '').strip()
    return linha

moveis_disponiveis['preco'] = moveis_disponiveis['preco'].apply(tratar_preco).astype(np.float64)
moveis_disponiveis
# Out:
#           id       data  vaga_disponivel  preco  ano-mes
# 0        857 2016-01-04            False    0.0  2016-01
# 1        857 2016-01-05            False    0.0  2016-01
# 2        857 2016-01-06            False    0.0  2016-01
# 3        857 2016-01-07            False    0.0  2016-01
# 4        857 2016-01-08            False    0.0  2016-01
# ...      ...        ...              ...    ...      ...
# 364995  3279 2016-12-29             True  140.0  2016-12
# 364996  3279 2016-12-30             True  140.0  2016-12
# 364997  3279 2016-12-31             True  140.0  2016-12
# 364998  3279 2017-01-01             True  140.0  2017-01
# 364999  3279 2017-01-02            False    0.0  2017-01
#
# [365000 rows x 5 columns]
